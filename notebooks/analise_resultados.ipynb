# %% [markdown]
# # Analise de Resultados\n\nNotebook de apoio para interpretar a comparacao entre Forca Bruta e Dijkstra.

# %%
import pandas as pd\n\ndf = pd.read_csv('../data/processed/performance_records.csv')\ndf

# %% [markdown]
# ## Escala de decisao\n\n1. Forca Bruta: usar apenas como validacao em N pequeno.\n2. Dijkstra em N pequeno: confirma o otimo com menor tempo.\n3. Dijkstra em N medio/grande: recomendado para resposta operacional.\n4. Prim: recomendado quando o objetivo e cobertura regional minima.
